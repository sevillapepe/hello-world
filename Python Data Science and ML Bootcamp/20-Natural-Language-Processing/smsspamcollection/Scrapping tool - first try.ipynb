# %%
from bs4 import BeautifulSoup
from requests import get
import pandas as pd
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
headers = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'})

# %%
sapo = "https://casa.sapo.pt/Venda/Apartamentos/?sa=11&or=10"
response = get(sapo, headers=headers)

# %%
print(response)
# Out:
# <Response [200]>

# %%
print(response.text[:10000])
# Out:
# <!DOCTYPE html>
#
# <html lang="pt">
# <head><title>
# 	Casas para Venda, Apartamentos Com Ofertas recentes no Distrito de Lisboa, CASA SAPO - Portal Nacional de Imobiliário
# </title><meta name="author" content="CASA SAPO - Portal Nacional de Imobiliário - Janela Digital SA" />
#     <meta name="application-name" content="CASA SAPO - Portal Nacional de Imobiliário" data-copyright="Janela Digital SA" data-generated-time="04/04/2020 16:17" />
#
# <meta name="content-language" content="pt" />
# <meta name="viewport" content="width=device-width, initial-scale=1.0" />
# <meta name="description" content="Casas para Venda, 30663 Apartamentos Com Ofertas recentes no Distrito de Lisboa, Deseja comprar casa? No maior Portal Imobiliário Nacional temos milhares de apartamentos e moradias em Lisboa, no Porto e por todo o país." />
# <meta name="keywords" content="Casas para Venda, Apartamentos Com Ofertas recentes no Distrito de Lisboa, venda, compra, comprar, casas, imóveis, apartamentos, moradias, terrenos, porto, lisboa" />
# <meta name="referrer" content="always" />
# <link rel="alternate" type="application/rss+xml" href="/News/Multimedia/RSS/CNCS.rss" title="Últimas Notícias CASA SAPO" />
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/favicon.ico?v=1" type="image/x-icon" rel="shortcut icon" />
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/apple-icon-57x57.png?v=1" type="image/png" rel="apple-touch-icon" sizes="57x57" />
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/apple-icon-60x60.png?v=1" type="image/png" rel="apple-touch-icon" sizes="60x60" />
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/apple-icon-72x72.png?v=1" type="image/png" rel="apple-touch-icon" sizes="72x72" />
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/apple-icon-76x76.png?v=1" type="image/png" rel="apple-touch-icon" sizes="76x76" />
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/apple-icon-114x114.png?v=1" type="image/png" rel="apple-touch-icon" sizes="114x114" />
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/apple-icon-120x120.png?v=1" type="image/png" rel="apple-touch-icon" sizes="120x120" />
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/apple-icon-144x144.png?v=1" type="image/png" rel="apple-touch-icon" sizes="144x144" />
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/apple-icon-152x152.png?v=1" type="image/png" rel="apple-touch-icon" sizes="152x152" />
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/apple-icon-180x180.png?v=1" type="image/png" rel="apple-touch-icon" sizes="180x180" />
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/android-icon-36x36.png?v=1" type="image/png" rel="icon" sizes="36x36" />
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/android-icon-48x48.png?v=1" type="image/png" rel="icon" sizes="48x48" />
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/android-icon-96x96.png?v=1" type="image/png" rel="icon" sizes="96x96" />
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/android-icon-192x192.png?v=1" type="image/png" rel="icon" sizes="192x192" />
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/favicon-16x16.png?v=1" type="image/png" rel="icon" sizes="16x16" />
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/favicon-32x32.png?v=1" type="image/png" rel="icon" sizes="32x32" />
# <link href="https://casa.sapo.pt/Themes/Global/Images/Social/favicon-16x16.png?v=1" rel="icon" />
# <link href="/manifest.json" rel="manifest" />
# <meta name="robots" content="index,follow" /><meta name="googlebot" content="index,follow" />
# 	<meta property="og:image" itemprop="image" content="https://casa.sapo.pt/Themes/Global/Images/Social/logo_fb.png" /><meta name="msapplication-config" content="/browserconfig.xml" /><meta name="theme-color" content="#222222" /><meta name="apple-mobile-web-app-capable" content="yes" /><meta name="apple-mobile-web-app-status-bar-style" content="#222222" />
# 	<link rel="canonical" href="https://casa.sapo.pt/comprar-apartamentos/ofertas-recentes/distrito.lisboa/" />
# 	<link rel="next" href="https://casa.sapo.pt/comprar-apartamentos/ofertas-recentes/distrito.lisboa/?pn=2" />
# 	<link rel="alternate" href="https://casa.sapo.pt/en_gb/buy-apartments/most-recent/district.lisboa/" hreflang="en" />
# 	<link rel="alternate" href="https://casa.sapo.pt/es_es/comprar-pisos-apartamentos/ofertas-recientes/distrito.lisboa/" hreflang="es" />
# 	<link rel="alternate" href="https://casa.sapo.pt/fr_fr/acheter-appartements/offres-recentes/quartier.lisboa/" hreflang="fr" />
# 	<link rel="alternate" href="https://casa.sapo.pt/comprar-apartamentos/ofertas-recentes/distrito.lisboa/" hreflang="pt" />
# 	<link rel="alternate" href="https://casa.sapo.pt/comprar-apartamentos/ofertas-recentes/distrito.lisboa/" hreflang="x-default" />
#         <script>
#             (function (w, d, s, l, i)
#             {
#                 w[l] = w[l] || []; w[l].push({
#                     'gtm.start':
#                         new Date().getTime(), event: 'gtm.js'
#                 }); var f = d.getElementsByTagName(s)[0],
#                     j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                         'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#             })(window, document, 'script', 'dataLayer', 'GTM-P7LPLK');
#         </script>
#
#         <script>
#             (function (w, d, s, l, i)
#             {
#                 w[l] = w[l] || []; w[l].push({
#                     'gtm.start':
#                         new Date().getTime(), event: 'gtm.js'
#                 }); var f = d.getElementsByTagName(s)[0],
#                     j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                         'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#             })(window, document, 'script', 'dataLayer', 'GTM-583JN6Z');
#         </script>
#
#     <script type="application/ld+json">
#     {
#         "@context": "http://schema.org",
#         "@type": "WebSite",
#         "url": "https://casa.sapo.pt",
#         "potentialAction":
#             {
#             "@type": "SearchAction",
#             "target": "https://casa.sapo.pt/Pesquisar/?fs={search_term_string}",
#             "query-input": "required name=search_term_string"
#         },
#         "author":
#         {
#             "@context" : "http://schema.org",
#             "@type" : "Organization",
#             "name" : "CASA SAPO - Portal Nacional de Imobiliário",
#             "url" : "https://casa.sapo.pt",
#             "logo" : "https://casa.sapo.pt/Themes/Global/Images/Backgrounds/logo.png",
#             "sameAs" : [ "http://www.facebook.com/CasaSapo.pt", "http://plus.google.com/+casasapo" ]
#         }
#     }
#     </script>
#     <script type="application/ld+json">
#     {
#         "@context": "http://schema.org",
#         "@type": "Organization",
#         "url": "https://casa.sapo.pt",
#         "logo" : "https://casa.sapo.pt/Themes/Global/Images/Backgrounds/logo.png",
#         "contactPoint": [
#             {
#                 "@type": "ContactPoint",
#                 "telephone": "+351-262840462",
#                 "contactType": "customer service"
#             }
#         ]
#     }
#     </script>
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.5.0/css/font-awesome.min.css" rel="preload" as="style" onload="this.onload=null; this.rel='stylesheet'" /><link href="/Themes/Global/mainClass.min.css?Version=637213309814374360" rel="stylesheet" /><link href="/Themes/Global/frontpage.min.css?Version=637209263121609105" rel="preload" as="style" onload="this.onload=null; this.rel='stylesheet'" /><link href="/Themes/Global/globalAsync.min.css?Version=637213339488323031" rel="preload" as="style" onload="this.onload=null; this.rel='stylesheet'" /><link href="/Themes/Global/CreditoHabitacaoMBCP.min.css?Version=637209263105875052" rel="stylesheet" /><link href="/Themes/Global/CreditoHabitacaoMBCP-Responsive.min.css?Version=637209263105925043" rel="preload" as="style" onload="this.onload=null; this.rel='stylesheet'" />
#     <script>
#         (function (w)
#         {
#             if (("serviceWorker" in navigator))
#             {
#                 w.addEventListener('load', function ()
#                 {
#                     try
#                     {
#                         var path = "/sw.min.js";
#
#                         var promise = navigator.serviceWorker.register(path);
#                         if (promise instanceof Promise)
#                         {
#                             promise.then(function (reg)
#                             {
#                                 reg.onupdatefound = function ()
#                                 {
#                                     reg.update();
#                                 };
#                             }, function (error)
#                             {
#                                 LogError(error, location.href, 0, 0, error);
#                             }).catch(function (error)
#                             {
#                                 LogError(error, location.href, 0, 0, error);
#                             });
#                         }
#                     }
#                     catch (e)
#                     {
#                         LogError(e.message, location.href, 0, 0, e);
#                     }
#                 });
#             }
#         })(window);
#     </script>
#
#     <script>
#         var lingua = 'pt_PT';
#         var basePath = '/';
#         var popupHeaderColor = "#71ac41";
#     </script>
#     <script src="/ScriptsV2/site/asynchandler.min.js?Version=637209263128441084"></script>
#     <script src="/ScriptsV2/site/header.min.js?Version=637209263128491059"></script>
#     <script>
# var CSRFTokenName = '_CSRFTOKEN';
# var CSRFToke

# %%
html_soup = BeautifulSoup(response.text, 'html.parser')

# %%
house_containers = html_soup.find_all('div', class_="searchResultProperty")

# %%
first = house_containers[0]
first.find_all('span')
# Out:
# [<span class="titleG3"></span>, <span>
#                          Apartamento T3, Cabeço da Fonte, Algueirão-Mem Martins, Sintra, Lisboa
#                      </span>, <span class="btnContactPVPI" id="MC_PropertyInList_repProperties_btnContactPVPINormal_0" onclick="ShowContactForm('0c72fa3d-f7b5-4998-b159-21ec053caf7c', '13', '6', false, false, '0'); return false;" style="z-index: 9999;" title="Contacte Anunciante">Contacte Anunciante</span>, <span>140 000 <strong title="Euro">€</strong></span>]

# %%
var_1=first.find_all('span')[3].text
var_1
# Out:
# '140\xa0000 €'

# %%
var_1=var_1.replace('\xa0','')
var_1
# Out:
# '140000 €'

# %%
#using itertools to retrieve the digits and turn it into a float
var_1=int(''.join(itertools.takewhile(str.isdigit, var_1)))
print(var_1,type(var_1))
# Out:
# 140000 <class 'int'>

# %%
#Location
location=first.find_all('p', class_="searchPropertyLocation")[0].text

# %%
location[7:location.find(',')]
# Out:
# '               Cabeço da Fonte'

# %%
#size in m2
first.find_all('p')[7]
# Out:
# <p>98m²</p>

# %%
#Property title
var2=first.find_all('p', class_="searchPropertyTitle")[0].text

# %%
var2=var2.replace('\n\r\n','')
var2=var2.replace('\n\r','')
var2=var2.replace('\n','')
var2=var2.replace('\r','')

# %%
var2
# Out:
# '                        Apartamento T3, Cabeço da Fonte, Algueirão-Mem Martins, Sintra, Lisboa                    '

# %%
#date add posted

#pd.to_datetime(first.find_all('div', class_="searchPropertyDate")[0].text[3:4])

# %%
#short description
first.find_all('p', class_="searchPropertyDescription")[0].text[7:-6]
# Out:
# '               Apartamento T3 (Cave ao nível de 1º andar com vista de Serra) situado na Urbanização cabeço da Fonte Algueirão, zona muito tranquila, muito perto de todos os serviços tais como transporte ferroviário, rodoviário, acesso ás (...)\r\n          '

# %%
#get all the links
for url in first.find_all('a'):
    print(url.get('href'))
# Out:
# /comprar-apartamento-t3-sintra-algueirao-mem-martins-cabeco-da-fonte-perto-escola,hospital,policia,transportes-publicos-tem-varandas,vista-para-cidade,vista-para-montanha-0c72fa3d-f7b5-4998-b159-21ec053caf7c.html
# %%
#i want the 2x size thumbnail, which can be found in the positions defined below
imgurl=p[p.find('data-original_2x=')+18:p.find('id=')-2]
imgurl
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f4c2f7af1fb0> in <module>
#       1 #i want the 2x size thumbnail, which can be found in the positions defined below
# ----> 2 imgurl=p[p.find('data-original_2x=')+18:p.find('id=')-2]
#       3 imgurl
#
# NameError: name 'p' is not defined

# %%
sapo_url = 'https://casa.sapo.pt/Venda/Apartamentos/?sa=11&lp=10000&or=10'
r = get(sapo_url, headers=headers)

# %%
titles = []
#created = []
prices = []
areas = []
zone = []
condition = []
descriptions = []
urls = []
thumbnails = []

# %%
n_pages = 0

for page in range(0,10):
    n_pages += 1
    sapo_url = 'https://casa.sapo.pt/Venda/Apartamentos/?sa=11&lp=100000&or=10'+'&pn='+str(page)
    r = get(sapo_url, headers=headers)
    page_html = BeautifulSoup(r.text, 'html.parser')
    house_containers = page_html.find_all('div', class_="searchResultProperty")
    if house_containers != []:
        for container in house_containers:
            
            # Price            
            price = container.find_all('span')[2].text
            if price == 'Contacte Anunciante':
                price = container.find_all('span')[3].text
                if price.find('/') != -1:
                    price = price[0:price.find('/')-1]
            if price.find('/') != -1:
                price = price[0:price.find('/')-1]
            
            price_ = [int(price[s]) for s in range(0,len(price)) if price[s].isdigit()]
            price = ''
            for x in price_:
                price = price+str(x)
            prices.append(int(price))

            # Zone
            location = container.find_all('p', class_="searchPropertyLocation")[0].text
            location = location[7:location.find(',')]
            zone.append(location)

            # Title
            name = container.find_all('span')[0].text
            titles.append(name)

            # Status
            status = container.find_all('p')[5].text
            condition.append(status)

            # Area
            m2 = container.find_all('p')[9].text
            if m2 != '-':
                m2 = m2.replace('\xa0','')
                m2 = float("".join(itertools.takewhile(str.isdigit, m2)))
                areas.append(m2)
                
            else:
                m2 = container.find_all('p')[7].text
                if m2 != '-':
                    m2 = m2.replace('\xa0','')
                    m2 = float("".join(itertools.takewhile(str.isdigit, m2)))
                    areas.append(m2)
                else:
                    areas.append(m2)

            # Creation date
            #date = pd.to_datetime(container.find_all('div', class_="searchPropertyDate")[0].text[21:31])
            #created.append(date)

            # Description
            desc = container.find_all('p', class_="searchPropertyDescription")[0].text[7:-6]
            descriptions.append(desc)

            # url
            link = 'https://casa.sapo.pt/' + container.find_all('a')[0].get('href')[1:-6]
            urls.append(link)

            # image
            img = str(container.find_all('img')[0])
            img = img[img.find('data-original_2x=')+18:img.find('id=')-2]
            thumbnails.append(img)
    else:
        break
    
    #sleep(randint(1,2))
    
print('You scraped {} pages containing {} properties.'.format(n_pages, len(titles)))
# Out:
# You scraped 10 pages containing 520 properties.

# %%
cols = ['Title', 'Zone', 'Price', 'Size (m²)', 'Status', 'Description', 'URL', 'Image']

lisboa = pd.DataFrame({'Title': titles,
                           'Price': prices,
                           'Size (m²)': areas,
                           'Zone': zone,
                           #'Date': created,
                           'Status': condition,
                           'Description': descriptions,
                           'URL': urls,
                           'Image': thumbnails})[cols]

lisboa.to_excel('lisboa_raw.xls')

# lisboa = pd.read_excel('lisboa_raw.xls')

# %%
lisboa
# Out:
#                                                  Title  \
# 0                              T1 em Outeiro de Polima
# 1
# 2
# 3    Apartamento T2 com logradouro na Graça com rem...
# 4                              Apartamento T2 - Lisboa
# 5                             Apartamento T3 em Lisboa
# 6                Apartamento T2 com terraço na Amadora
# 7                             Apartamento T4 em Lisboa
# 8
# 9
# 10
# 11
# 12
# 13   »100% Financiamento! Apartamento T2 no Condomí...
# 14                     Excelente T2 com estúdio de som
# 15   Apartamento T3 em Campo de Ourique, Para Remod...
# 16   Venha conhecer este T1 numa praceta calma e co...
# 17   Apartamento T2 com logradouro na Graça com rem...
# 18
# 19
# 20   Apartamento T2 na Baixa de Lisboa (entre a Rua...
# 21                                         T2 Odivelas
# 22                   Apartamento T2 - Para Remodelação
# 23   100% Financiamento - Apartamento T2 - Santa Clara
# 24                     Apartamentos T2 Novos na Ramada
# 25               Apartamentos T2 com terraço na Ramada
# 26                     Apartamentos T2 Novos na Ramada
# 27                             T1 em Outeiro de Polima
# 28
# 29
# ..                                                 ...
# 490
# 491
# 492
# 493
# 494
# 495
# 496
# 497
# 498
# 499
# 500
# 501
# 502
# 503
# 504
# 505                    Apartamento T1 no Casal da Mira
# 506
# 507
# 508
# 509
# 510                          Apartamento T2 na Amadora
# 511  Apartamento T1 NOVO c/ Parqueamento e Arrecadação
# 512
# 513
# 514
# 515
# 516
# 517
# 518
# 519
#
#                                                   Zone   Price Size (m²)  \
# 0                                 São Domingos de Rana  168000        89
# 1                                      Cabeço da Fonte  140000       116
# 2                                         Campo Grande  310000        80
# 3                                          São Vicente  205000        60
# 4                                                Beato  125000        70
# 5                                      Penha de França  330000       140
# 6                                         Mina de Água       2        94
# 7                                         Misericórdia  500000       105
# 8                                             Venteira  240000       170
# 9                                Algueirão-Mem Martins  188000       105
# 10                               Algueirão-Mem Martins  183000       105
# 11                                            Alvalade  440000        90
# 12                              Massamá e Monte Abraão  139000        96
# 13                                             Sacotes  150000       102
# 14                                São Domingos de Rana  240000        89
# 15                                    Campo de Ourique  415000       100
# 16                         Alto de São João (São João)  172000        55
# 17                                         São Vicente  205000        60
# 18                                 Carcavelos e Parede  385000       111
# 19                                             Olivais  210000        83
# 20                                   Santa Maria Maior  270000        81
# 21                                   Pontinha e Famões  250000       135
# 22                        Centro (Santa Iria de Azoia)   99900        65
# 23                         Alta de Lisboa (Ameixoeira)  220000       102
# 24                         Bairro da Carochia (Ramada)       2        96
# 25                         Bairro da Carochia (Ramada)       2       137
# 26                         Bairro da Carochia (Ramada)  250000        96
# 27                                São Domingos de Rana  168000        89
# 28                                     Cabeço da Fonte  140000       116
# 29                                        Campo Grande  310000        80
# ..                                                 ...     ...       ...
# 490                                       Mina de Água  105000        40
# 491                              Sacavém e Prior Velho  490000       216
# 492                 Santo António dos Cavaleiros e ...  245000       126
# 493                                              Mafra  259900       201
# 494                 Santo António dos Cavaleiros e ...  104900        66
# 495                                           Odivelas  335000       120
# 496                                  Pontinha e Famões  290000       112
# 497                              Algueirão-Mem Martins  180000       114
# 498                                  Pontinha e Famões  325000       128
# 499                                      Santo António  449000        93
# 500                                           Odivelas  152500        60
# 501                                       Rio de Mouro  135000        88
# 502                                          Alfragide  188900       104
# 503                                       Misericórdia  110000        37
# 504                                           Odivelas  191000       135
# 505                                       Mina de Água  140000        75
# 506                                           Venteira  128500        68
# 507                                           Odivelas  191000       135
# 508                                             Loures  158500       110
# 509                                 Cacém e São Marcos  129500        93
# 510                                       Mina de Água  155000        86
# 511                           Casal da Mira (São Brás)  140000        76
# 512                                             Lumiar  262650        60
# 513                                             Lumiar  618000       168
# 514                                             Lumiar  525300       146
# 515                                             Lumiar  525300       121
# 516                                             Lumiar  545900       122
# 517                                             Lumiar  262500        60
# 518                                             Lumiar  628300       168
# 519                                             Lumiar  638600       168
#
#             Status                                        Description  \
# 0            Usado                 Apartamento T1 em Urbanização e...
# 1         Renovado                 Apartamento T3 (Cave ao nível d...
# 2            Usado                 O apartamento está em exclusivo...
# 3            Usado                 Temos protocolo de contingência...
# 4    Por recuperar                 Apartamento T2 - Lisboa  Oportu...
# 5            Usado                 Otimo apartamento T3 com AC e G...
# 6            Usado                 Apartamento T2 com acesso a ter...
# 7       Recuperado                 Apartamento de 5 ass. com uma á...
# 8            Usado                 (ref:114556)apartamento t3, loc...
# 9             Novo                 (ref: (telefone) Excelente Apar...
# 10            Novo                 (ref: (telefone) Excelente Apar...
# 11           Usado                 (ref:C (telefone) Trata se de 3...
# 12           Usado                 (ref: (telefone) Excelente apar...
# 13           Usado                 »100% Financiamento! Apartament...
# 14           Usado                 T2 muito bem situado na Urbaniz...
# 15           Usado                 Apartamento de Tipologia T3 em ...
# 16           Usado                 Venha conhecer este T1 numa pra...
# 17           Usado                 Temos protocolo de contingência...
# 18           Usado                 T4, virado nascente/poente, Pró...
# 19           Usado                 Apartamento com 4 assoalhadas e...
# 20           Usado                 LOCALIZAÇÃO: Inserida emplena b...
# 21           Usado                 Apartamento T2 com uma magnific...
# 22           Usado                 Apartamento para remodelar, dua...
# 23           Usado                 Apartamento T2 com possibilidad...
# 24            Novo                 Apartamentos T2 Novos  EM EXCLU...
# 25            Novo                 Apartamentos T2 Novos na Ramada...
# 26            Novo                 Apartamentos T2 Novos  EM EXCLU...
# 27           Usado                 Apartamento T1 em Urbanização e...
# 28        Renovado                 Apartamento T3 (Cave ao nível d...
# 29           Usado                 O apartamento está em exclusivo...
# ..             ...                                                ...
# 490          Usado                 Vende-se apartamento T1 com arr...
# 491          Usado                 Apartamento T3 inserido no Cond...
# 492          Usado                 Excelente apartamento com áreas...
# 493          Usado                 Venha visitar este T3 de Constr...
# 494          Usado                 T2 Remodelado em 2010 com canal...
# 495          Usado                 Apartamento T2 de LUXO nas Coli...
# 496          Usado                 Excelente T2 no centro da Ponti...
# 497          Usado                 Apartamento com boas áreas em b...
# 15   rtamento T3, Campo de Ourique, Lisboa, Campo d...
# 16   rtamento T1, Alto de São João (São João), Penh...
# 17   rtamento T2, São Vicente, Lisboa, São Vicente ...
# 18   rtamento T4, Carcavelos e Parede, Cascais, Lis...
# 19   rtamento T3, Olivais, Lisboa, Olivais em Lisbo...
# 20   rtamento T2, Santa Maria Maior, Lisboa, Santa ...
# 21   rtamento T2, Pontinha e Famões, Odivelas, Lisb...
# 22   rtamento T2 Triplex, Centro (Santa Iria de Azo...
# 23   rtamento T2 Com garagem, Alta de Lisboa (Ameix...
# 24   rtamento T2 Com garagem, Bairro da Carochia (R...
# 25   rtamento T2 Com garagem, Bairro da Carochia (R...
# 26   rtamento T2 Com garagem, Bairro da Carochia (R...
# 27   rtamento T1, São Domingos de Rana, Cascais, Li...
# 28   rtamento T3, Cabeço da Fonte, Algueirão-Mem Ma...
# 29   rtamento T2, Campo Grande, Alvalade, Lisboa, A...
# ..                                                 ...
# 490  rtamento T1, Mina de Água, Amadora, Lisboa, Mi...
# 491  rtamento T3, Sacavém e Prior Velho, Loures, Li...
# 492  rtamento T3, Santo António dos Cavaleiros e Fr...
# 493  rtamento T3, Mafra, Lisboa em Mafra" data-erro...
# 494  rtamento T2, Santo António dos Cavaleiros e Fr...
# 495  rtamento T2, Odivelas, Lisboa em Odivelas" dat...
# 496  rtamento T2, Pontinha e Famões, Odivelas, Lisb...
# 497  rtamento T3, Algueirão-Mem Martins, Sintra, Li...
# 498  rtamento T2, Pontinha e Famões, Odivelas, Lisb...
# 499  rtamento T3, Santo António, Lisboa, Santo Antó...
# 500  rtamento T2, Odivelas, Lisboa em Odivelas" dat...
# 501  rtamento T2, Rio de Mouro, Sintra, Lisboa, Rio...
# 502  rtamento T4, Alfragide, Amadora, Lisboa, Alfra...
# 503  rtamento T1, Misericórdia, Lisboa, Misericórdi...
# 504  rtamento T4, Odivelas, Lisboa em Odivelas" dat...
# 505  rtamento T1, Mina de Água, Amadora, Lisboa, Mi...
# 506  rtamento T2, Venteira, Amadora, Lisboa, Ventei...
# 507  rtamento T4, Odivelas, Lisboa em Odivelas" dat...
# 508  rtamento T3, Loures, Lisboa em Loures" data-er...
# 509  rtamento T2, Cacém e São Marcos, Sintra, Lisbo...
# 510  rtamento T2, Mina de Água, Amadora, Lisboa, Mi...
# 511  rtamento T1 Com garagem, Casal da Mira (São Br...
# 512  rtamento T1, Lumiar, Lisboa, Lumiar em Lisboa"...
# 513  rtamento T3, Lumiar, Lisboa, Lumiar em Lisboa"...
# 514  rtamento T2, Lumiar, Lisboa, Lumiar em Lisboa"...
# 515  rtamento T2, Lumiar, Lisboa, Lumiar em Lisboa"...
# 516  rtamento T2, Lumiar, Lisboa, Lumiar em Lisboa"...
# 517  rtamento T1, Lumiar, Lisboa, Lumiar em Lisboa"...
# 518  rtamento T3, Lumiar, Lisboa, Lumiar em Lisboa"...
# 519  rtamento T3, Lumiar, Lisboa, Lumiar em Lisboa"...
#
# [520 rows x 8 columns]
